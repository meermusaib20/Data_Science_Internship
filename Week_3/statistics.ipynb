# %%
import pandas as pd
df = pd.read_csv(
    "C:/Users/mimusaib/Desktop/Data_Science_Internship/Week_3/Sample - Superstore.csv",
    encoding="latin1"
)

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Row ID          4997.5000
# Postal Code    56430.5000
# Sales             54.4900
# Quantity           3.0000
# Discount           0.2000
# Profit             8.6665
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Row ID          2885.163629
# Postal Code    32063.693350
# Sales            623.245101
# Quantity           2.225110
# Discount           0.206452
# Profit           234.260108
# dtype: float64

# %%
target = (df["Sales"])

# %%
target.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(target,kde = True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.boxplot(y=target)
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# **Bussiness Question :**
# ***Is the average sales per order greater than 200?***

# %% [markdown]
# ***Hypothesis definition :***
# H0: μ ≤ 200   (average sales is 200 or less)
# H1: μ > 200   (average sales is greater than 200)

# %%
from scipy import stats

t_stat, p = stats.ttest_1samp(target, 200)

print("t-stat:", t_stat)
print("p-value:", p)
# Out:
# t-stat: 4.789294302012744
# p-value: 1.6977434726361302e-06

# %% [markdown]
# **Results :**
# ***Hypothesis Testing on Sales***
#
# We tested whether the average sales per order exceed 200.
#
# H₀: μ ≤ 200
# H₁: μ > 200
#
# A one-sample t-test was conducted on 9,994 sales records.
#
# Results:
#
# t-statistic = 4.79
#
# p-value = 1.69 × 10⁻⁶
#
# Since the p-value is significantly less than 0.05, we reject the null hypothesis.
# Therefore, there is strong statistical evidence that the average sales per order
# are greater than 200.
